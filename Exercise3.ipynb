# %%
import numpy as np

def sum_first_last(arr):
    return arr[0]+arr[-1]
print(sum_first_last(np.array([10, 20, 30, 40, 50])))
# Out:
# 60

# %%
#Sum first and last elements
#Complete the function sum_first_last with one parameter, array arr.

#Return the sum of the first and last element of the passed arr argument
#test the code
