# %%
import numpy as np

def float_array(num1, num2):
    return np.arange(num1,num2,dtype=np.float)
print(np.arange(2,4,dtype=np.float64))
# Out:
# [2. 3.]

# %%
#Create float array
#Using NumPy, create a function float_array with two parameters, number 1 num1 and number 2 num2.
#Return a NumPy array from num1 to num2-1 in the float data type.
#test the code by using print 
#
